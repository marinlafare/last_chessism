# %%
import os
from code_for_llm_utils import *

# %%
create_root_files_for_llm()
create_service_files_for_llm()
create_routers_file_for_llm()
create_operations_file_for_llm()
create_database_file_for_llm()
# Out:
# Successfully wrote content to one.txt
# Successfully wrote content to two.txt
# Successfully wrote content to three.txt
# Successfully wrote content to four.txt
# Successfully wrote content to five.txt
